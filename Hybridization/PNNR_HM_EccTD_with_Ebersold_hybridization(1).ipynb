# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import math
from numpy import diff
from tqdm import tqdm
from scipy import interpolate
from scipy.interpolate import interp1d
from pycbc.types import TimeSeries, FrequencySeries
from lal import MSUN_SI, MTSUN_SI, G_SI, PC_SI, C_SI
import scipy.optimize
import lal
from pycbc import waveform, types
from pycbc.waveform import get_td_waveform
from pycbc.types import TimeSeries, FrequencySeries
from lal import MSUN_SI, MTSUN_SI, G_SI, PC_SI, C_SI
import scipy.optimize

# %%
### Calling NR waveforms (SAS simulations used)

# %%
#modify filename to include directory path to file, 
#for e.g. '/home/SXSfiles/1365_rhOverM_Asymptotic_GeometricUnits_CoM.h5' 
simulation = '1365_rhOverM_Asymptotic_GeometricUnits_CoM.h5'  
tref = 340.0 #tref is the start time of usable SXS waveforms, check metadata of simulation to obtain it
sims = simulation.split('_')[0]
lp = 3  # change accordingly
mp = 3
mode = 'l'+str(lp)+'_m'+str(mp)
with h5py.File(simulation, 'r') as hdf:     
    temp=hdf['OutermostExtraction.dir']['Y_'+mode+'.dat']
    test=np.array(temp)
        
x1=test[:,0]
y1=test[:,1]    
z1=test[:,2]

plotband=np.where(x1>=tref)
print(plotband)

x1=x1[plotband]
x1=x1-x1[0]
y1=y1[plotband]    
z1=z1[plotband]
print(len(x1))

tot=y1-1j*z1
amp=abs(tot)
ph=np.angle(tot)
phase_NR=np.unwrap(ph)
w=np.absolute(diff(phase_NR)/diff(x1))
phi0=phase_NR[0]


plt.figure(figsize=(15,5))
plt.plot(x1,y1,label='$h_+$')
plt.plot(x1,z1,label='$h_X$')
plt.title("NR",fontsize=18)
plt.ylabel("Strain", fontsize=15)
plt.xlabel("t/M", fontsize=15)
plt.grid()
plt.legend(loc=2,prop={'size': 15})

print('time:',x1[np.argmax(amp)],'\n index:',np.argmax(amp),'\n length:',len(amp))
# Out:
# (array([  602,   603,   604, ..., 14850, 14851, 14852]),)
# 14251
# time: 3564.772879657674
#  index: 12759
#  length: 14251

# %% [markdown]
# ### Parameters for generating inspiral waveform

# %%
#these parameters have been obtained from Hinder et.al. 2019
q=2
eref=0.06
cl=lref=1.926
e0=0.145 #initial eccentricity at xlow, will change if xlow changes
eta=neu=nu=q/(1+q)**2 
xref=0.075 
xlow=0.045 #xlow can be chosen to be any value, we have chosen 0.045 to be the start of our hybrids
G=c=M=d=1
d0=1
M0=1
M2=M/(1+q)
M1=M2*q
modetopolfac=4*(5/(64*np.pi))**(1/2) # 22 mode factor

#lref = (lref + np.pi) % (2 * np.pi) - np.pi  #use only for SXS:BBH:1167
#cl = lref

hl2m2pVec=y1
hl2m2cVec=z1
tVec=x1
M_SI=M*MSUN_SI
D_SI=(10**(6))*PC_SI
tVec_SI=tVec*M*MTSUN_SI;
hpVec_SI=hl2m2pVec*G_SI*M_SI/D_SI/C_SI/C_SI;
hcVec_SI=hl2m2cVec*G_SI*M_SI/D_SI/C_SI/C_SI;

# %%
delta_t_NR=np.max(abs(np.diff(tVec_SI)))   
print(delta_t_NR)

delta_t_common=delta_t_NR
t=tVec_SI

#### interpolation to sample data at equispaced time points
tVec_NR = np.linspace(t.min(),t.max(),int((t.max()-t.min())/delta_t_common)) 
hp_NR_sample = interp1d(t,hpVec_SI,kind='cubic')
hp_NR_int = hp_NR_sample(tVec_NR)
hc_NR_sample = interp1d(t,hcVec_SI,kind='cubic')
hc_NR_int = hc_NR_sample(tVec_NR)

#### converting to PyCBC TimeSeries
mergIdx_NR=np.argmax(np.abs(hp_NR_int+1j*hc_NR_int))
hpVec_NR = TimeSeries(hp_NR_int,delta_t_common,epoch=0)
hcVec_NR = TimeSeries(hc_NR_int,delta_t_common,epoch=0)

plt.figure(figsize=(15,5))
plt.plot(tVec_SI,hpVec_SI,label='NR') 
plt.plot(tVec_SI,hcVec_SI,label='NR') 
#plt.plot(hpVec_NR.sample_times,hpVec_NR,'k--',label='Interpolation')
plt.plot(tVec_NR,hp_NR_int,'k--',label='Interpolation')
plt.plot(tVec_NR,hc_NR_int,'k--',label='Interpolation')
plt.title("Interpolated NR",fontsize=18)
plt.ylabel("Strain", fontsize=15)
plt.xlabel("t/M", fontsize=15)
plt.grid()
plt.legend(loc=2,prop={'size': 15},ncol=2)
print(len(t),len(hpVec_NR),tVec[-1])
# Out:
# 3.6508926751409893e-06
# 14251 5010 3713.8625359389107

# %%
phiC=phase_NR[mergIdx_NR]         
#tC_NR=hpVec_NR.sample_times[mergIdx_NR]
#phiC=phase_NR[len(hpVec_NR)]         
tC_NR=max(hpVec_NR.sample_times)
Delta=math.sqrt(1-(4*neu))
eta=nu=neu
gamma=EulerGamma= 0.577215664901

# %run GW_functions.ipynb
conv=M*MTSUN_SI               #total mass (needed to convert PN time t to t/M)

#Formula to compute f from a given x
def freq(i):
    return(i**(3/2)/(M*MTSUN_SI*math.pi))
 
f_low=freq(xlow)            #Lower frequency of EccTD wf which is in our hands
f_ref=freq(xref)            #Ref frequency of EccTD wf

####################################################

#Calculating ecc at xlow for generating EccTD wf-->eccentricity evolution Eq. (4.17a,b) Moore et. al.(2016)

x=xlow                         #x=point where eccentricity is required
v=math.sqrt(x)
vref=math.sqrt(xref)
xie=v**3
xiref=vref**3

#Gives e at xie with b.c.--> e=eref when xie=xiref

e=eref*(xiref/xie)**(19/18)*epsilon(xie, eta)/epsilon(xiref, eta) # this is using Moore evolution equation
#not using this eccentricity since we have used EccentricTD evolution to generate the initial eccentricity(e0) values

print(e) 
print(f_low)
# Out:
# 0.14989892087434276
# 616.9065279526923

# %%
print(tC_NR)
# Out:
# 0.018287321409781215

# %% [markdown]
# ### Generating EccentricTD

# %%
hpVec_PN, hcVec_PN = get_td_waveform(approximant='EccentricTD', mass1=M1, mass2=M2, 
                         delta_t=delta_t_common, 
                         f_lower=f_low, 
                         eccentricity=e0,
                         distance=d)

# %%
plt.figure(figsize=(12,5))
tVec_PN_shifted=tC_NR+hpVec_PN.sample_times#-hpVec_PN.sample_times[-1]
plt.plot(tVec_PN_shifted/conv,hpVec_PN,label='Initial eccentricity $e_0=%1.3f$' %e)
plt.title("PN",fontsize=18)
plt.ylabel("Strain", fontsize=15)
plt.xlabel("t/M", fontsize=15)
plt.grid()
plt.legend(loc=2,prop={'size': 15})
print(len(hpVec_PN))
# Out:
# 25454

# %%
print(tVec_PN_shifted[-1])
# Out:
# 0.018283670670144827

# %% [markdown]
# ### obtaining EccentricTD phase

# %%
phase_EccTD = waveform.utils.phase_from_polarizations(hpVec_PN/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)), hcVec_PN/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)))

# %%
tVec_PN_GM=tVec_PN_shifted/conv
tVec_NR_GM=tVec_NR/conv
hpVec_PN_GM=hpVec_PN/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))
hcVec_PN_GM=hcVec_PN/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))

# %%
plt.plot(hpVec_PN.sample_times,phase_EccTD)

# %%
tC_NR=tC_NR/conv
tC_NR
# Out:
# 3712.7915399588064

# %% [markdown]
# ### Obtaining parameters for generating Ebersold+ amplitudes

# %%
tVec_PN=tVec_PN_GM
tC_NR=tC_NR

xi_ref=xref**(3/2)
v_ref=xi_ref**(1/3)
#input initial params
x0=xlow
xi0=x0**(3/2)
v0=xi0**(1/3)
#e0=(eref*(xi_ref/xi0)**(19/18))*(epsilon(xi0, eta)/epsilon(xi_ref, eta))
l0=mean_anomaly(xi_ref, xi0, lref, eta)
theta=((5*M/(eta))**(1/8))*(tC_NR-tVec_PN)**(-1/8)
theta0=((5*M/(eta))**(1/8))*(tC_NR-tVec_PN[0])**(-1/8)
fVec=x_from_t(theta, theta0, e0, M, eta)

# %%
print(tC_NR-tVec_PN)
# Out:
# [1.88671183e+04 1.88663771e+04 1.88656359e+04 ... 2.22364124e+00
#  1.48241714e+00 7.41193034e-01]

# %%
xiVec=(np.pi*M*fVec)
#print('xiVec:', xiVec)
xVec=xiVec**(2/3)
print('xVec:', xVec)
vVec=xiVec**(1/3)
# Out:
# xVec: [0.04485664 0.0448571  0.04485755 ...        nan        nan        nan]
# /home/croyt/pycbc/lib/python3.8/site-packages/pycbc/types/array.py:417: RuntimeWarning: invalid value encountered in power
#   return self._data ** other

# %%
#selct +ve frequencies
plotIdx2=np.nonzero(fVec>=0)
fVec=fVec[plotIdx2]
xiVec=xiVec[plotIdx2]
xVec=xVec[plotIdx2]
vVec=vVec[plotIdx2]
maxPNidx=len(xVec)
print(maxPNidx)
# Out:
# 25391

# %%
len(xVec), len(phase_EccTD)
# Out:
# (25391, 25454)

# %% [markdown]
# ### Ebersold+ amplitudes

# %%
j=0
omega=[]
hlm_real=[]
hlm_imag=[]
hlm_abs=[]
for i in tqdm(xVec):
    v=math.sqrt(i)
    v0=math.sqrt(x0)
    xie=v**3
    xi0=v0**3
    l=mean_anomaly(xie, xi0, l0, eta)
    e=e0*(xi0/xie)**(19/18)*epsilon(xie, eta)/epsilon(xi0, eta)
    #psi=phase_TT2(v, v0, phiC, eta)+W(xie, xi0, eta, e0, l)
    psi=phase_EccTD[j]
    j=j+1
    xi=l   #use xi for amplitude (xie is being used for v**3)
    x=i
    
    #change according to the hlm required, check GW_functions.ipynb for the function definitions and arguements
    h=amplitude_22(xi,x,nu,e) 
    hlm=8*math.sqrt(math.pi/5)*M*neu*i*h*((np.e)**(complex(0,-1)*mp*psi/2))/d
    hlm0 = hlm *M0/d0
    hlm_real.append(hlm0.real)
    hlm_imag.append(hlm0.imag)
    hlm_abs.append(abs(hlm0))
print(len(hlm_real))
# Out:
# 100%|████████████████████████████████████████████████████████| 25391/25391 [00:24<00:00, 1051.21it/s]
# 25391

# %%
mp, j
# Out:
# (2, 25391)

# %%
plt.figure(figsize=(15,5))
plt.plot(tVec_PN_GM[:maxPNidx],hlm_real[:],'r',label='Initial eccentricity $e_0=%1.3f$' %e0)
plt.plot(tVec_PN_GM[:maxPNidx],hlm_abs[:],'g')
plt.title("PN", fontsize=18)
plt.ylabel("Strain", fontsize=15)
plt.xlabel("Time", fontsize=15)
#plt.xlim(xmin=-500)
#plt.xlim(xmax=2500)
plt.ylim(-0.5e0,0.5e0)
plt.grid()
plt.legend(loc=2,prop={'size': 15})
#plt.savefig("4.png",dpi=300)

# %%
plt.figure(figsize=(15,5))
plt.plot(tVec_NR_GM, hpVec_NR/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)), label='NR')
plt.plot(tVec_PN_GM[:maxPNidx],hlm_real,'r',label='PN $e_0=%1.3f$' %e0)
#plt.plot(tVec_PN_GM[:maxPNidx],hlm_imag,'r',label='PN $e_0=%1.3f$' %e0)
plt.ylim(ymax=0.5)
plt.ylim(ymin=-0.5)
plt.xlim(xmin=-200)
#plt.xlim(xmax=6700)
plt.title("PN-NR",fontsize=18)
plt.ylabel("Strain", fontsize=15)
plt.xlabel("t/M", fontsize=15)
plt.grid()
plt.legend(loc=2,prop={'size': 15})

# %% [markdown]
# ### Hybridization routine

# %%
t1Idx_NR=np.where(tVec_NR_GM>=1000.0)[0][0]
t1Idx_PN=np.where(tVec_PN_GM>=1000.0)[0][0]

t2Idx_NR=np.where(tVec_NR_GM>=2000.0)[0][0]
t2Idx_PN=np.where(tVec_PN_GM>=2000.0)[0][0]

# %%
print(tVec_NR_GM[t1Idx_NR],tVec_PN_GM[t1Idx_PN])
# Out:
# 1000.9262695096339 1000.83132327724

# %%
stretch=abs(tVec_NR_GM[t1Idx_NR]-tVec_NR_GM[t2Idx_NR])
print('NR matching window in t/M:',stretch)
print('NR matching indices:',t1Idx_NR,'\t',t2Idx_NR)

stretch=abs(tVec_PN_GM[t1Idx_PN]-tVec_PN_GM[t2Idx_PN])
print('\nPN matching window in t/M:',stretch)
print('PN matching indices:',t1Idx_PN,'\t',t2Idx_PN)
# Out:
# NR matching window in t/M: 999.4735463318258
# NR matching indices: 689 	 1377
#
# PN matching window in t/M: 999.3787730147376
# PN matching indices: 4353 	 5041

# %%
print(t2Idx_NR - t1Idx_NR,t2Idx_PN-t1Idx_PN)
# Out:
# 688 688

# %%
hpVec_NR_GM=hp_NR_int/(G_SI*M_SI/D_SI/C_SI/C_SI)
hcVec_NR_GM=hc_NR_int/(G_SI*M_SI/D_SI/C_SI/C_SI)

# %%
if (t2Idx_NR - t1Idx_NR)<(t2Idx_PN-t1Idx_PN):
    t2Idx_NR = t2Idx_NR+1

# %%
hpVec_NR_crop=hpVec_NR_GM[t1Idx_NR:t2Idx_NR]
hcVec_NR_crop=hcVec_NR_GM[t1Idx_NR:t2Idx_NR]
tVec_NR_crop=tVec_NR_GM[t1Idx_NR:t2Idx_NR]

def PN_crop(pnshiftIdx):
    hpVec_PN_crop=np.array(hlm_real[t1Idx_PN+pnshiftIdx:t2Idx_PN+pnshiftIdx])
    #hpVec_PN_crop=np.array(hlm_imag[t1Idx_PN+pnshiftIdx:t2Idx_PN+pnshiftIdx])
    tVec_PN_crop=tVec_PN_GM[t1Idx_PN+pnshiftIdx:t2Idx_PN+pnshiftIdx]
    return(tVec_PN_crop, hpVec_PN_crop)

# %%
def deltaPNNR(param_Vec, h_NR_crop, h_PN_crop):
    #return(np.sum(abs(h_NR_crop-param_Vec[2]*h_PN_crop*((np.e)**(1j*(param_Vec[0]+param_Vec[1]))))))
    return(np.sum(abs(h_NR_crop-h_PN_crop*((np.e)**(1j*(param_Vec[0]+param_Vec[1]))))))

# %%
timeshiftIdxVec=np.arange(-500,500,1)

param_Vec_initial=[np.pi/2,0]
deltaVec=[]
paramVecmin=[]

for timeshiftIdx in timeshiftIdxVec:
    tVec_PN_crop, hpVec_PN_crop=PN_crop(timeshiftIdx)
    param_Vec_minimized = scipy.optimize.fmin(func=deltaPNNR, x0=param_Vec_initial, args=(hpVec_NR_crop,hpVec_PN_crop))
    deltaVec.append(deltaPNNR(param_Vec_minimized,hpVec_NR_crop,hpVec_PN_crop))
    paramVecmin.append(param_Vec_minimized)
# Out:
# Optimization terminated successfully.
#          Current function value: 9.719931
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 8.826691
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.942121
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.090133
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.317513
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.648937
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.087278
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.640074
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.300389
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.073458
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.953568
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.941934
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.039829
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.243212
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.559585
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.983345
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.520552
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.167083
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.918043
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.759027
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 8.643799
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 9.540657
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 10.440639
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 11.339059
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 12.235670
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 13.130037
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 14.020401
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 14.908003
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.790889
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 16.670168
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 17.545080
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 18.415309
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 19.280387
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 20.140873
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 20.995511
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 21.844949
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.688537
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 23.526029
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 24.358061
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 25.182803
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 26.002136
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 26.813339
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.619069
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 28.415958
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 29.207324
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 29.989180
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 30.765397
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 31.531689
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 32.291817
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.042054
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.785365
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 34.518839
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 35.244466
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 35.960459
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.667715
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 37.365667
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.053792
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.733163
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.401583
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 40.061568
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 41.191422
#          Iterations: 30
#          Function evaluations: 55
# Optimization terminated successfully.
#          Current function value: 40.553033
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.906093
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.247100
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 38.580358
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.901494
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.215443
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 36.517417
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 35.812620
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 35.096085
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.373199
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 33.638830
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 32.898533
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 32.147025
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.390012
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.622273
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.849067
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.065924
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.277177
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.479504
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.676061
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.864579
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.047028
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 24.222724
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.391652
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.555333
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 21.711793
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.864005
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.009156
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.150714
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 18.285463
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.416832
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.542251
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.664052
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 14.781751
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.894960
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.005129
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 12.111599
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 11.215386
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 10.316390
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 9.415234
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.513381
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.613300
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.723320
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.877239
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.134756
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.516510
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.031685
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.676788
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.454077
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.357440
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.390424
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.549185
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.838990
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.258102
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.811242
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.492060
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.293479
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.171211
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.071764
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.977531
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 9.883295
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 10.787539
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 11.689835
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 12.588734
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.485606
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 14.378105
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.267543
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.152411
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.033295
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.910299
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 18.781171
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.649303
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.509900
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 21.367556
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.217244
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.063382
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.901737
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 24.735132
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.561519
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.381196
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.194958
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.000391
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.800334
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.590987
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.376097
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.151248
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.920728
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 32.679631
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 33.432742
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.174666
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.910689
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 35.635108
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 36.353151
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.059560
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.758749
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 38.446479
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.126140
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.794540
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 40.454059
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 41.102459
#          Iterations: 30
#          Function evaluations: 55
# Optimization terminated successfully.
#          Current function value: 40.275270
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.615189
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.947336
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.267332
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 37.579848
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.880462
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.174003
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 35.456011
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 34.731148
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.995300
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.252673
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 32.499774
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 31.740006
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 30.970940
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 30.194614
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 29.410224
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 28.618002
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.819043
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.011912
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 26.198956
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 25.377901
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 24.551555
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 23.717388
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.878465
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.032066
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 21.181344
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 20.323926
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 19.461878
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 18.594353
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 17.722021
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 16.845482
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.963863
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.078611
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 14.188914
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 13.295676
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 12.398864
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 11.499293
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 10.596411
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 9.690939
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 8.784013
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.875335
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.966743
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.062573
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.181884
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.392495
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.751261
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.272015
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.952214
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.792038
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.786944
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.936999
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.246411
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.715252
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.346502
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.127685
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.006912
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.913014
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.824485
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 8.736217
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 9.646450
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 10.555325
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 11.461356
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 12.364627
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 13.264991
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 14.162112
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.055215
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.944721
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 16.830031
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 17.710686
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 18.587506
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 19.458792
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 20.325966
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 21.187017
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.043340
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.893306
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 23.737954
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 24.575974
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 25.408346
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 26.233472
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.052642
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.864159
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 28.669422
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 29.466408
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 30.256907
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 31.038688
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 31.813529
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 32.579340
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.337763
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 34.086891
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 34.828112
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 35.559951
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.283114
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.996951
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 37.701346
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.396485
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.081417
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.757326
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 40.422046
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 41.059870
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 40.406580
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.743295
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.069632
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 38.386134
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.692756
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 36.989717
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 36.277303
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 35.555416
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.824712
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.084784
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 33.336604
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 32.579156
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.814219
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.040137
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.259063
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.469119
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.672686
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.867668
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.056671
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.237388
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.412638
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 24.579914
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.742240
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.896933
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.047161
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 21.190440
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.329112
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.461992
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 18.589835
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.713466
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.831468
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.946426
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.055711
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 14.162603
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.264612
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 12.363819
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 11.459867
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 10.552648
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 9.643419
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.731518
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.817955
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.903045
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.988207
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.076531
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.183752
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.390447
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.787156
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.392616
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.202938
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.212340
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.420287
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.833112
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.454309
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.261861
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.159533
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.073626
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.990477
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.906829
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.822290
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 9.735884
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 10.646898
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 11.556286
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 12.461687
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.365049
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 14.264484
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.160027
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.052935
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.940227
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.824912
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 18.703400
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.578637
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.447451
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 21.312352
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.170912
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.024318
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.871855
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 24.712892
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.548494
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.376634
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.199148
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.013563
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.822300
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.622197
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.416206
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.200829
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.979255
#          Iterations: 28
# ...
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.781878
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.849072
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.914584
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.979124
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.042686
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.105673
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.168224
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.328022
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 1.769341
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 1.499018
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 1.530934
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 1.868167
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 2.492905
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 3.388288
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 4.321731
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 5.254787
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 6.185896
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 7.116462
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.044542
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 8.972029
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 9.896517
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 10.820364
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 11.740693
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 12.660339
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 13.575941
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 14.490819
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 15.400962
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 16.309529
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 17.212678
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 18.113962
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.009138
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 19.902168
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 20.788396
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 21.672207
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 22.548516
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 23.422144
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 24.287567
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 25.150056
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.003632
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 26.854030
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 27.694807
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 28.532172
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 29.359205
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.182602
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 30.994956
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 31.803460
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 32.600212
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 33.392911
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.173148
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 34.949142
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 35.711966
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 36.470367
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.214894
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 37.954831
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 38.680193
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 39.400808
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 40.106154
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 40.806609
#          Iterations: 28
#          Function evaluations: 53
# Optimization terminated successfully.
#          Current function value: 41.491106
#          Iterations: 30
#          Function evaluations: 55
# Optimization terminated successfully.
#          Current function value: 40.436399
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.729724
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 39.013900
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 38.286610
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 37.550511
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.803460
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 36.047954
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 35.282019
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 34.507992
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 33.724071
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 32.932431
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 32.131440
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 31.323114
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 30.505987
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 29.681920
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 28.849617
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 28.010760
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 27.164282
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 26.311576
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 25.451899
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 24.586335
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 23.714449
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 22.837030
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 21.953936
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 21.065675
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 20.172381
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 19.274301
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 18.371824
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 17.464953
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 16.554317
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 15.639692
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 14.721924
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 13.800583
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 12.876715
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 11.949702
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 11.020766
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 10.089125
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 9.156156
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 8.220946
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.284961
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.347286
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.409256
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.470824
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.584270
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.900632
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.422188
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.145761
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.082480
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.240909
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 2.617567
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.200382
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 3.979134
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 4.908776
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 5.842051
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 6.774333
#          Iterations: 29
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 7.704907
#          Iterations: 29
#          Function evaluations: 54

# %%
minIdx=np.argmin(deltaVec)
phaseshift_min=paramVecmin[minIdx][0]
angularshift_min=paramVecmin[minIdx][1]
#ampshift_min=paramVecmin[minIdx][2]
timeshiftIdx_min=timeshiftIdxVec[minIdx]
minIdx, timeshiftIdx_min, phaseshift_min, angularshift_min #ampshift_min
# Out:
# (603, 103, -0.000918066529154834, 0.000926101386547089)

# %%
tau_new=tVec_PN_GM-(timeshiftIdx_min*delta_t_common/conv)
#tau_newc=tVec_PN_GM-(timeshiftIdx_minc*delta_t_common/conv)
hpVec_PN_phaseshifted=np.array(hlm_real)*(np.e)**(1j*phaseshift_min+angularshift_min)
hcVec_PN_phaseshifted=np.array(hlm_imag)*(np.e)**(1j*phaseshift_min+angularshift_min)

# %%
plt.figure(figsize=(15,5))
plt.plot(tVec_NR_GM,hp_NR_int/(G_SI*M_SI/D_SI/C_SI/C_SI),color='lightcoral',linewidth=2,label='NR')
plt.plot(tau_new[:maxPNidx],hpVec_PN_phaseshifted[:],color='brown',linestyle='--',linewidth=2,label='PN')
plt.plot(tVec_NR_GM,hc_NR_int/(G_SI*M_SI/D_SI/C_SI/C_SI),color='chartreuse',linewidth=2,label='NR')
plt.plot(tau_new[:maxPNidx],hcVec_PN_phaseshifted[:],color='darkgreen',linestyle='--',linewidth=2,label='PN')
plt.title("Minimized PN-NR (EccTD+3PNAmp)", fontsize=25)
plt.ylabel("Strain", fontsize=20)
plt.xlabel("t/M", fontsize=20)

plt.axvline(x=tVec_NR_GM[int(t1Idx_NR)],linewidth=2, color='gray')
plt.axvline(x=tVec_NR_GM[int(t2Idx_NR)],linewidth=2, color='gray')
plt.axvspan(tVec_NR_GM[int(t1Idx_NR)], tVec_NR_GM[int(t2Idx_NR)],  alpha=0.5, color='silver')

plt.ylim(ymax=0.5)
plt.ylim(ymin=-0.5)
plt.xlim(xmin=500)
plt.xlim(xmax=3500)
#plt.xticks(fontsize=20)
#plt.yticks(fontsize=20)
plt.legend(loc=2,prop={'size': 22},ncol=2)
plt.grid()
#plt.savefig('0184TT2.jpg',dpi=600)
# Out:
# /home/croyt/pycbc/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /home/croyt/pycbc/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
hyb_time=[]
hyb_hp=[]
hyb_hc=[]

T1_PN=t1Idx_PN
T2_PN=t2Idx_PN

T1_NR=t1Idx_NR
T2_NR=t2Idx_NR

# %%
for i in tau_new[:T1_PN+timeshiftIdx_min]:
    hyb_time.append(i)

for i in hpVec_PN_phaseshifted[:T1_PN+timeshiftIdx_min]:
    hyb_hp.append(i)
    
for i in hcVec_PN_phaseshifted[:T1_PN+timeshiftIdx_min]:
    hyb_hc.append(i)

# %%
for i,j in tqdm(zip(range(T1_NR,T2_NR), range((T1_PN+timeshiftIdx_min),(T2_PN+timeshiftIdx_min)))):
    tau=float((tVec_NR_GM[i]-tVec_NR_GM[int(T1_NR)])/(tVec_NR_GM[int(T2_NR)]-tVec_NR_GM[int(T1_NR)]))
    hpval=tau*hp_NR_int[i]/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))+(1-tau)*(hpVec_PN_phaseshifted[j])
    hcval=tau*hc_NR_int[i]/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))+(1-tau)*(hcVec_PN_phaseshifted[j])
    
    hyb_hp.append(hpval)
    hyb_hc.append(hcval)
    hyb_time.append(tVec_NR_GM[i])
# Out:
# 688it [00:00, 33326.57it/s]

# %%
for i in tVec_NR_GM[T2_NR:]:
    hyb_time.append(i)
for i in hp_NR_int[T2_NR:]:
    hyb_hp.append(i/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)))
for i in hc_NR_int[T2_NR:]:
    hyb_hc.append(i/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)))

# %%
plt.figure(figsize=(15,5))
plt.plot(hyb_time,np.real(hyb_hp))
plt.plot(hyb_time,np.real(hyb_hc))
plt.plot(hyb_time,np.abs(np.real(hyb_hp)+1j*np.real(hyb_hc)))
plt.plot(tVec_NR_GM,hp_NR_int/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)),'--')
plt.plot(tVec_NR_GM,hc_NR_int/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)),'--')
plt.plot(tVec_NR_GM,abs(hp_NR_int/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))+1j*hc_NR_int/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI))),'--')
#plt.plot(hpVec_PN.sample_times/(MTSUN_SI)+3000,hpVec_PN/(modetopolfac*(G_SI*M_SI/D_SI/C_SI/C_SI)),'--')
plt.xlim(xmin=-1000)
# Out:
# (-1000.0, 16421.048405013215)

# %% [markdown]
# ### Saving hybrids to an HDF file

# %%
print(len(hyb_hp),len(hyb_hc),len(hyb_time))
# Out:
# 14354 14354 14354

# %%
DataArray = np.transpose([hyb_time, np.real(hyb_hp), np.real(hyb_hc)])

# %%
hf = h5py.File(sims+'_EccTD_Ebersold_HM.h5', 'a') ## change name of file to be created as required

# %%
#hf.create_dataset('l2_m2', data=DataArray)
hf.create_dataset(mode, data=DataArray)
# Out:
# <HDF5 dataset "l5_m4": shape (14499, 3), type "<f8">

# %%
hf.close()

# %% [markdown]
# ### Checking the HDF file

# %%
hf = h5py.File(sims+'_EccTD_Ebersold_HM.h5','r')

# %%
print(hf.keys())
# Out:
# <KeysViewHDF5 ['l2_m1', 'l2_m2', 'l3_m2', 'l3_m3', 'l4_m3', 'l4_m4', 'l5_m4', 'l5_m5']>

# %%
testd = hf.get(mode)

# %%
print(len(testd[:,0]),testd[0,0])
# Out:
# 14499 -5682.514221258819

# %%
plt.figure(figsize=(15,5))
plt.plot(testd[:,0],testd[:,1]*G_SI*M_SI/D_SI/C_SI/C_SI)
plt.plot(testd[:,0],testd[:,2]*G_SI*M_SI/D_SI/C_SI/C_SI)
#plt.xlim(xmin=-1000)

# %%
hf.close()
